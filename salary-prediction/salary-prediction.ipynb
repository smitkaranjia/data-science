# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import pickle

# %%
df = pd.read_csv('../input/salary-data-with-age-and-experience/Salary_Data.csv')
df.head()

# %%
df.describe()

# %%
x = df.iloc[:,:2]
y = df.iloc[:,2]

# %%
x.shape,y.shape

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score , mean_squared_error

# %%
lreg = LinearRegression()
lreg.fit(x_train,y_train)

# %%
y_test,pred

# %%
pred = lreg.predict(x_test)
r2_score(y_test,pred)*100

# %%
exp = float(input('Input Experience'))
age = int(input('Input age'))
val = np.array([exp,age])
val = val.reshape(1,-1)
if val[0][1] < 21:
    print('Age should be more than 21')
else:
    print('The expected salary is:',lreg.predict(val))

# %%
pickle.dump(lreg,open('model.pkl', 'wb'))
